# %%
from ase.io import read,write
import numpy as np
import os
from ase.filters import UnitCellFilter
from ase.optimize import BFGS
from ase.filters import Filter
from ase.eos import calculate_eos
import copy
import glob
from pyace import PyACECalculator

# %%
potfilename='../../models/SiH-ACE-25.yaml'
acepot = PyACECalculator(potfilename)

# %%
names=['SiH2_s3B1d', 'SiH3', 'SiH4', 'Si2H6']

# %%
for name in names:
    print(name)
    atoms=read(f'../../data/paper/molecules/{name}/POSCAR')

    atoms.calc=acepot
    dyn = BFGS(atoms)
    dyn.run(fmax=0.0001)
    write(f'../../data/paper/molecules/{name}/{name}_ace_relaxed.xyz', atoms)
    print(atoms.get_all_distances())
# Out:
# SiH2_s3B1d
#       Step     Time          Energy          fmax
# BFGS:    0 13:32:37       -9.630526        2.375068
# BFGS:    1 13:32:37       -9.727943        1.456682
# BFGS:    2 13:32:37       -9.819465        0.832556
# BFGS:    3 13:32:37       -9.847800        0.849553
# BFGS:    4 13:32:37       -9.899590        0.716071
# BFGS:    5 13:32:37       -9.932102        0.488620
# BFGS:    6 13:32:37       -9.940802        0.102885
# BFGS:    7 13:32:37       -9.941167        0.012974
# BFGS:    8 13:32:37       -9.941182        0.000135
# BFGS:    9 13:32:37       -9.941182        0.000001
# [[0.         1.50511983 1.50511983]
#  [1.50511983 0.         2.22446388]
#  [1.50511983 2.22446388 0.        ]]
# SiH3
#       Step     Time          Energy          fmax
# BFGS:    0 13:32:37      -14.756709        0.373623
# BFGS:    1 13:32:37      -14.759443        0.339748
# BFGS:    2 13:32:37      -14.774724        0.212117
# BFGS:    3 13:32:37      -14.776666        0.139461
# BFGS:    4 13:32:37      -14.777964        0.072747
# BFGS:    5 13:32:37      -14.778774        0.019295
# BFGS:    6 13:32:37      -14.778813        0.004355
# BFGS:    7 13:32:37      -14.778814        0.000159
# BFGS:    8 13:32:37      -14.778814        0.000007
# [[0.         1.48861635 1.48861636 1.48861636]
#  [1.48861635 0.         2.39839818 2.39839818]
#  [1.48861636 2.39839818 0.         2.39839814]
#  [1.48861636 2.39839818 2.39839814 0.        ]]
# SiH4
#       Step     Time          Energy          fmax
# BFGS:    0 13:32:37      -19.805673        0.038665
# BFGS:    1 13:32:37      -19.805748        0.028850
# BFGS:    2 13:32:37      -19.805841        0.000066
# [[0.         1.48069328 1.48069328 1.48069328 1.48069328]
#  [1.48069328 0.         2.417962   2.417962   2.417962  ]
#  [1.48069328 2.417962   0.         2.417962   2.417962  ]
#  [1.48069328 2.417962   2.417962   0.         2.417962  ]
#  [1.48069328 2.417962   2.417962   2.417962   0.        ]]
# Si2H6
#       Step     Time          Energy          fmax
# BFGS:    0 13:32:37      -32.912622        0.215248
# BFGS:    1 13:32:37      -32.914775        0.087328
# BFGS:    2 13:32:37      -32.915832        0.047090
# BFGS:    3 13:32:37      -32.916024        0.052883
# BFGS:    4 13:32:37      -32.916674        0.035111
# BFGS:    5 13:32:37      -32.916844        0.032405
# BFGS:    6 13:32:37      -32.917008        0.034057
# BFGS:    7 13:32:37      -32.917137        0.040212
# BFGS:    8 13:32:37      -32.917218        0.022481
# BFGS:    9 13:32:37      -32.917233        0.005325
# BFGS:   10 13:32:37      -32.917234        0.000293
# BFGS:   11 13:32:37      -32.917234        0.000020
# [[0.         2.33907057 1.47977367 1.47977368 1.47977368 3.16354026
#   3.16354027 3.16354027]
#  [2.33907057 0.         3.16354026 3.16354027 3.16354027 1.47977367
#   1.47977368 1.47977368]
#  [1.47977367 3.16354026 0.         2.41124305 2.41124305 4.35019345
#   3.62078585 3.62078585]
#  [1.47977368 3.16354027 2.41124305 0.         2.41124307 3.62078585
#   3.62078585 4.35019348]
#  [1.47977368 3.16354027 2.41124305 2.41124307 0.         3.62078585
#   4.35019348 3.62078585]
#  [3.16354026 1.47977367 4.35019345 3.62078585 3.62078585 0.
#   2.41124305 2.41124305]
#  [3.16354027 1.47977368 3.62078585 3.62078585 4.35019348 2.41124305
#   0.         2.41124307]
#  [3.16354027 1.47977368 3.62078585 4.35019348 3.62078585 2.41124305
#   2.41124307 0.        ]]

# %%
### GAP22
from quippy.potential import Potential

# %%
gap22=Potential(param_filename='../../models/GAP22/GAP_Si_H_PRM.xml')

# %%
names=['SiH2_s3B1d', 'SiH3', 'SiH4', 'Si2H6']
for name in names:
    print(name)
    atoms=read(f'../../data/paper/molecules/{name}/POSCAR')

    atoms.calc=gap22
    dyn = BFGS(atoms)
    dyn.run(fmax=0.0001)
    write(f'../../data/paper/molecules/{name}/{name}_gap22_relaxed.xyz', atoms)
    print(atoms.get_all_distances())
# Out:
# SiH2_s3B1d
#       Step     Time          Energy          fmax
# BFGS:    0 22:26:21     -131.694989        1.247082
# BFGS:    1 22:26:21     -131.744131        1.100999
# BFGS:    2 22:26:21     -131.925156        0.678335
# BFGS:    3 22:26:21     -131.945052        0.411885
# BFGS:    4 22:26:21     -131.950228        0.244468
# BFGS:    5 22:26:21     -131.952945        0.026869
# BFGS:    6 22:26:21     -131.953020        0.003596
# BFGS:    7 22:26:21     -131.953021        0.000331
# BFGS:    8 22:26:21     -131.953021        0.000014
# [[0.         1.4827513  1.4827513 ]
#  [1.4827513  0.         2.26115194]
#  [1.4827513  2.26115194 0.        ]]
# SiH3
#       Step     Time          Energy          fmax
# BFGS:    0 22:26:21     -147.150609        1.281625
# BFGS:    1 22:26:21     -147.216057        0.957484
# BFGS:    2 22:26:21     -147.320815        0.895293
# BFGS:    3 22:26:21     -147.336901        0.798442
# BFGS:    4 22:26:21     -147.371777        0.411758
# BFGS:    5 22:26:21     -147.380875        0.079652
# BFGS:    6 22:26:21     -147.381236        0.005617
# BFGS:    7 22:26:21     -147.381238        0.000075
# [[0.         1.4701341  1.47013412 1.47013412]
#  [1.4701341  0.         2.29159175 2.29159175]
#  [1.47013412 2.29159175 0.         2.29159208]
#  [1.47013412 2.29159175 2.29159208 0.        ]]
# SiH4
#       Step     Time          Energy          fmax
# BFGS:    0 22:26:21     -161.318106        1.043990
# BFGS:    1 22:26:21     -161.371590        0.746169
# BFGS:    2 22:26:21     -161.424629        0.038743
# BFGS:    3 22:26:21     -161.424772        0.000167
# BFGS:    4 22:26:22     -161.424772        0.000000
# [[0.         1.43244127 1.43244127 1.43244127 1.43244127]
#  [1.43244127 0.         2.3391668  2.3391668  2.3391668 ]
#  [1.43244127 2.3391668  0.         2.3391668  2.3391668 ]
#  [1.43244127 2.3391668  2.3391668  0.         2.3391668 ]
#  [1.43244127 2.3391668  2.3391668  2.3391668  0.        ]]
# Si2H6
#       Step     Time          Energy          fmax
# BFGS:    0 22:26:22     -297.788293        1.380897
# BFGS:    1 22:26:22     -297.967216        1.343572
# BFGS:    2 22:26:22     -298.765489        2.771340
# BFGS:    3 22:26:22     -298.923218        1.180168
# BFGS:    4 22:26:22     -299.012482        0.305938
# BFGS:    5 22:26:22     -299.068848        0.163613
# BFGS:    6 22:26:22     -299.080895        0.183452
# BFGS:    7 22:26:22     -299.083254        0.109884
# BFGS:    8 22:26:22     -299.085599        0.063971
# BFGS:    9 22:26:22     -299.086999        0.017534
# BFGS:   10 22:26:22     -299.087170        0.002752
# BFGS:   11 22:26:22     -299.087174        0.000958
# BFGS:   12 22:26:22     -299.087174        0.000354
# BFGS:   13 22:26:22     -299.087174        0.000046
# [[0.         2.32650114 1.53688946 1.53688945 1.53688945 3.40152483
#   3.40152484 3.40152484]
#  [2.32650114 0.         3.40152483 3.40152484 3.40152484 1.53688946
#   1.53688945 1.53688945]
#  [1.53688946 3.40152483 0.         2.25603482 2.25603482 4.73837453
#   4.16683335 4.16683335]
#  [1.53688945 3.40152484 2.25603482 0.         2.25603479 4.16683335
#   4.16683337 4.73837455]
#  [1.53688945 3.40152484 2.25603482 2.25603479 0.         4.16683335
#   4.73837455 4.16683337]
#  [3.40152483 1.53688946 4.73837453 4.16683335 4.16683335 0.
#   2.25603482 2.25603482]
#  [3.40152484 1.53688945 4.16683335 4.16683337 4.73837455 2.25603482
#   0.         2.25603479]
#  [3.40152484 1.53688945 4.16683335 4.73837455 4.16683337 2.25603482
#   2.25603479 0.        ]]
